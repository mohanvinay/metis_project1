# %%
from script1 import catg_to_dummy,create_season_flag
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
data=pd.read_csv('/Users/jmx948/work/tech/repos/metis_project1/merged_data_v2.csv')
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0_x                          alt_title    director_x  \
# 0           0             2  10 Things I Hate About You (1999)           NaN
# 1           1             3                    10 Years (2012)  Jamie Linden
# 2           2             5               The 11th Hour (2007)           NaN
# 3           3             6                   127 Hours (2010)   Danny Boyle
# 4           4             7                   12 Rounds (2009)  Renny Harlin
#
#    domestic_gross              mojo_slug  opening_per_theater  \
# 0        38178166  10thingsihateaboutyou                 3668
# 1          203373                10years                 7569
# 2          707343               11thhour                15213
# 3        18335230               127hours                 2333
# 4        12234694               12rounds                 2286
#
#    opening_weekend_take  production_budget release_date_wide  \
# 0               8330681           30000000        1999-03-31
# ...

# %%
#Transformation of categorical variable - director
column_name='director_x'
data_2=catg_to_dummy(data,column_name,25)
pd.set_option('display.max_columns', 200)
data_2.head()
# Out:
#     Unnamed: 0  Unnamed: 0_x                   alt_title          director_x  \
# 11          11            17                 2012 (2009)     Roland Emmerich
# 46          46            71                  8MM (1999)     Joel Schumacher
# 72          72           122        Air Force One (1997)   Wolfgang Petersen
# 89          89           147  All About My Mother (1999)     Pedro Almodovar
# 93          93           154   All the Real Girls (2003)  David Gordon Green
#
#     domestic_gross         mojo_slug  opening_per_theater  \
# 11       166112167              2012                19165
# 46        36663315               8mm                 6013
# 72       172956409       airforceone                12720
# 89         8272296  allaboutmymother                12590
# 93          549666   alltherealgirls                 6569
#
#     opening_weekend_take  production_budget release_date_wide  \
# 11              65237614          200000000        2009-11-13
# ...

# %%
#Transformation of categorical variable - rating
column_name='rating'
data_3=catg_to_dummy(data_2,column_name,25)
data_3.head()
# Out:
#     Unnamed: 0  Unnamed: 0_x                   alt_title          director_x  \
# 11          11            17                 2012 (2009)     Roland Emmerich
# 46          46            71                  8MM (1999)     Joel Schumacher
# 72          72           122        Air Force One (1997)   Wolfgang Petersen
# 89          89           147  All About My Mother (1999)     Pedro Almodovar
# 93          93           154   All the Real Girls (2003)  David Gordon Green
#
#     domestic_gross         mojo_slug  opening_per_theater  \
# 11       166112167              2012                19165
# 46        36663315               8mm                 6013
# 72       172956409       airforceone                12720
# 89         8272296  allaboutmymother                12590
# 93          549666   alltherealgirls                 6569
#
#     opening_weekend_take  production_budget release_date_wide  \
# 11              65237614          200000000        2009-11-13
# ...

# %%
#Transformation of categorical variable - studio
column_name='studio'
data_4=catg_to_dummy(data_3,column_name,5)
data_4.head()
# Out:
#      Unnamed: 0  Unnamed: 0_x                 alt_title       director_x  \
# 11           11            17               2012 (2009)  Roland Emmerich
# 107         107           169  American Gangster (2007)     Ridley Scott
# 115         115           177    American Sniper (2014)   Clint Eastwood
# 135         135           213          Anonymous (2011)  Roland Emmerich
# 148         148           229          Apollo 13 (1995)       Ron Howard
#
#      domestic_gross         mojo_slug  opening_per_theater  \
# 11        166112167              2012                19165
# 107       130164645  americangangster                14264
# 115       347251832    americansniper                25111
# 135         4463292         anonymous                 3856
# 148       173837933          apollo13                11540
#
#      opening_weekend_take  production_budget release_date_wide  \
# 11               65237614          200000000        2009-11-13
# ...

# %%
cols = data_4.columns
cols = cols.map(lambda x: x.replace(' ', '_') if isinstance(x, (str, unicode)) else x)
data_4.columns = cols
cols = data_4.columns
cols = cols.map(lambda x: x.replace('M.', 'M') if isinstance(x, (str, unicode)) else x)
data_4.columns = cols
cols = data_4.columns
cols = cols.map(lambda x: x.replace('Andy_&_Lana_Wachowski', 'Wachowski') if isinstance(x, (str, unicode)) else x)
data_4.columns = cols
cols = data_4.columns
cols = cols.map(lambda x: x.replace('S.', 'S') if isinstance(x, (str, unicode)) else x)
data_4.head()
# Out:
#      Unnamed:_0  Unnamed:_0_x                 alt_title       director_x  \
# 11           11            17               2012 (2009)  Roland Emmerich
# 107         107           169  American Gangster (2007)     Ridley Scott
# 115         115           177    American Sniper (2014)   Clint Eastwood
# 135         135           213          Anonymous (2011)  Roland Emmerich
# 148         148           229          Apollo 13 (1995)       Ron Howard
#
#      domestic_gross         mojo_slug  opening_per_theater  \
# 11        166112167              2012                19165
# 107       130164645  americangangster                14264
# 115       347251832    americansniper                25111
# 135         4463292         anonymous                 3856
# 148       173837933          apollo13                11540
#
#      opening_weekend_take  production_budget release_date_wide  \
# 11               65237614          200000000        2009-11-13
# ...

# %%
#genre
#release_date

# %%
lm = smf.ols(formula='domestic_gross ~ Antoine_Fuqua + Cameron_Crowe + Christopher_Nolan + Clint_Eastwood + David_Gordon_Green + Dennis_Dugan + Jason_Reitman + Joel_Schumacher + Kevin_Macdonald + M_Night_Shyamalan + Martin_Scorsese + Pedro_Almodovar + Richard_Linklater + Ridley_Scott + Robert_Zemeckis + Roger_Donaldson + Roland_Emmerich + Ron_Howard + Steven_Soderbergh + Steven_Spielberg + Tim_Burton + Wolfgang_Petersen + Woody_Allen + opening_per_theater + opening_weekend_take + production_budget + widest_release + runtime_minutes', data=data_4).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         domestic_gross   R-squared:                       0.846
# Model:                            OLS   Adj. R-squared:                  0.790
# Method:                 Least Squares   F-statistic:                     15.12
# Date:                Fri, 16 Oct 2015   Prob (F-statistic):           1.94e-18
# Time:                        11:52:29   Log-Likelihood:                -1716.2
# No. Observations:                  91   AIC:                             3482.
# Df Residuals:                      66   BIC:                             3545.
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------
# ...
