# %%
import pandas

# %%
data1 = pandas.read_csv('boxofficedata.csv')

# %%
data1.head()
# Out:
#    Unnamed: 0                          alt_title         director  \
# 0           0                 10,000 B.C. (2008)  Roland Emmerich
# 1           1              102 Dalmatians (2000)              NaN
# 2           2  10 Things I Hate About You (1999)              NaN
# 3           3                    10 Years (2012)     Jamie Linden
# 4           4                  11 Flowers (2013)              NaN
#
#    domestic_gross              mojo_slug  opening_per_theater  \
# 0        94784201                10000bc                10518
# 1        66957026          102dalmatians                 7353
# 2        38178166  10thingsihateaboutyou                 3668
# 3          203373                10years                 7569
# 4            9213              11flowers                 1758
#
#    opening_weekend_take  production_budget release_date_limited  \
# 0              35867488          105000000                  NaN
# ...

# %%
data2 = pandas.read_csv('metacritic.csv')

# %%
data2.head()
# Out:
#    Unnamed: 0 complete         director                        genre  \
# 0           0     True       Gil Junger            [Comedy, Romance]
# 1           1     True     Jamie Linden     [Drama, Comedy, Romance]
# 2           2     True  Roland Emmerich  [Adventure, Drama, Fantasy]
# 3           3     True    Stephen Herek  [Adventure, Comedy, Family]
# 4           4     True       Kevin Lima             [Comedy, Family]
#
#                      metacritic_page  metascore num_critic_reviews  \
# 0  /movie/10-things-i-hate-about-you         70     [18, 7, 1, 26]
# 1                    /movie/10-years         61     [7, 11, 0, 18]
# 2                    /movie/10000-bc         34     [4, 8, 17, 29]
# 3              /movie/101-dalmatians         49      [8, 9, 3, 20]
# 4              /movie/102-dalmatians         35     [7, 5, 12, 24]
#
#    num_user_ratings   num_user_reviews rating release_date  runtime_minutes  \
# ...

# %%
merged_data = data1.merge(data2,on='title')

# %%
merged_data
# Out:
#       Unnamed: 0_x                                    alt_title  \
# 0                2            10 Things I Hate About You (1999)
# 1                3                              10 Years (2012)
# 2                5                         The 11th Hour (2007)
# 3                6                             127 Hours (2010)
# 4                7                             12 Rounds (2009)
# 5                9                        13 Going on 30 (2004)
# 6               10                               13 Sins (2014)
# 7               12                            13 Tzameti (2006)
# 8               13                                  1408 (2007)
# 9               14                             16 Blocks (2006)
# 10              15                              17 Again (2009)
# 11              17                                  2012 (2009)
# 12              19                                  2046 (2005)
# 13              20                  20 Feet from Stardom (2013)
# ...

# %%
len(data1)
# Out:
# 3728

# %%
len(data2)
# Out:
# 4765

# %%
len(merged_data)
# Out:
# 2444

# %%
merged_data.to_csv('merged_data.csv')

# %%
tmp = merged_data.dropna()

# %%
len(tmp)
# Out:
# 0

# %%
merged_data.head()
# Out:
#    Unnamed: 0_x                          alt_title    director_x  \
# 0             2  10 Things I Hate About You (1999)           NaN
# 1             3                    10 Years (2012)  Jamie Linden
# 2             5               The 11th Hour (2007)           NaN
# 3             6                   127 Hours (2010)   Danny Boyle
# 4             7                   12 Rounds (2009)  Renny Harlin
#
#    domestic_gross              mojo_slug  opening_per_theater  \
# 0        38178166  10thingsihateaboutyou                 3668
# 1          203373                10years                 7569
# 2          707343               11thhour                15213
# 3        18335230               127hours                 2333
# 4        12234694               12rounds                 2286
#
#    opening_weekend_take  production_budget release_date_limited  \
# 0               8330681           30000000                  NaN
# 1                 22707                NaN                  NaN
# ...

# %%
merged_data.count()
# Out:
# Unnamed: 0_x            2444
# alt_title               2444
# director_x              1540
# domestic_gross          2408
# mojo_slug               2444
# opening_per_theater     2378
# opening_weekend_take    2378
# production_budget       1193
# release_date_limited     209
# release_date_wide       2430
# title                   2434
# widest_release          2387
# worldwide_gross         2085
# year_x                  2432
# Unnamed: 0_y            2444
# complete                2434
# director_y              2433
# genre                   2431
# metacritic_page         2434
# metascore               2392
# num_critic_reviews      2434
# num_user_ratings        2348
# num_user_reviews        2434
# rating                  2389
# release_date            2433
# runtime_minutes         2392
# studio                  2409
# unable to retrieve        10
# user_score              2434
# year_y                  2433
# dtype: int64

# %%
data1.count()
# Out:
# Unnamed: 0              3728
# alt_title               3728
# director                2172
# domestic_gross          3653
# mojo_slug               3728
# opening_per_theater     3548
# opening_weekend_take    3548
# production_budget       1591
# release_date_limited     293
# release_date_wide       3718
# title                   3723
# widest_release          3576
# worldwide_gross         2821
# year                    3721
# dtype: int64

# %%
data = merged_data.drop(['release_data_limited','unable to retrieve'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-489581bcc0b4> in <module>()
# ----> 1 data = merged_data.drop([['release_data_limited','unable to retrieve']])
#
# //anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    1614                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1615             else:
# -> 1616                 new_axis = axis.drop(labels, errors=errors)
#    1617             dropped = self.reindex(**{axis_name: new_axis})
#    1618             try:
#
# //anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in drop(self, labels, errors)
#    2730         """
#    2731         labels = com._index_labels_to_array(labels)
# -> 2732         indexer = self.get_indexer(labels)
#    2733         mask = indexer == -1
#    2734         if mask.any():
#
# ...

# %%
merged_data.columns
# Out:
# Index([u'Unnamed: 0_x', u'alt_title', u'director_x', u'domestic_gross',
#        u'mojo_slug', u'opening_per_theater', u'opening_weekend_take',
#        u'production_budget', u'release_date_limited', u'release_date_wide',
#        u'title', u'widest_release', u'worldwide_gross', u'year_x',
#        u'Unnamed: 0_y', u'complete', u'director_y', u'genre',
#        u'metacritic_page', u'metascore', u'num_critic_reviews',
#        u'num_user_ratings', u'num_user_reviews', u'rating', u'release_date',
#        u'runtime_minutes', u'studio', u'unable to retrieve', u'user_score',
#        u'year_y'],
#       dtype='object')

# %%
data = merged_data

# %%
data.drop('unable to retrieve',axis=1)
# Out:
#       Unnamed: 0_x                                    alt_title  \
# 0                2            10 Things I Hate About You (1999)
# 1                3                              10 Years (2012)
# 2                5                         The 11th Hour (2007)
# 3                6                             127 Hours (2010)
# 4                7                             12 Rounds (2009)
# 5                9                        13 Going on 30 (2004)
# 6               10                               13 Sins (2014)
# 7               12                            13 Tzameti (2006)
# 8               13                                  1408 (2007)
# 9               14                             16 Blocks (2006)
# 10              15                              17 Again (2009)
# 11              17                                  2012 (2009)
# 12              19                                  2046 (2005)
# 13              20                  20 Feet from Stardom (2013)
# ...

# %%
data.count()
# Out:
# Unnamed: 0_x            2444
# alt_title               2444
# director_x              1540
# domestic_gross          2408
# mojo_slug               2444
# opening_per_theater     2378
# opening_weekend_take    2378
# production_budget       1193
# release_date_limited     209
# release_date_wide       2430
# title                   2434
# widest_release          2387
# worldwide_gross         2085
# year_x                  2432
# Unnamed: 0_y            2444
# complete                2434
# director_y              2433
# genre                   2431
# metacritic_page         2434
# metascore               2392
# num_critic_reviews      2434
# num_user_ratings        2348
# num_user_reviews        2434
# rating                  2389
# release_date            2433
# runtime_minutes         2392
# studio                  2409
# unable to retrieve        10
# user_score              2434
# year_y                  2433
# dtype: int64

# %%
data = data.drop('unable to retrieve',axis=1)

# %%
data = data.drop('release_date_limited',axis=1)

# %%
data.count()
# Out:
# Unnamed: 0_x            2444
# alt_title               2444
# director_x              1540
# domestic_gross          2408
# mojo_slug               2444
# opening_per_theater     2378
# opening_weekend_take    2378
# production_budget       1193
# release_date_wide       2430
# title                   2434
# widest_release          2387
# worldwide_gross         2085
# year_x                  2432
# Unnamed: 0_y            2444
# complete                2434
# director_y              2433
# genre                   2431
# metacritic_page         2434
# metascore               2392
# num_critic_reviews      2434
# num_user_ratings        2348
# num_user_reviews        2434
# rating                  2389
# release_date            2433
# runtime_minutes         2392
# studio                  2409
# user_score              2434
# year_y                  2433
# dtype: int64

# %%
data.to_csv('merged data.v2.csv')

# %%
tmp = data.dropna()

# %%
tmp.count()
# Out:
# Unnamed: 0_x            956
# alt_title               956
# director_x              956
# domestic_gross          956
# mojo_slug               956
# opening_per_theater     956
# opening_weekend_take    956
# production_budget       956
# release_date_wide       956
# title                   956
# widest_release          956
# worldwide_gross         956
# year_x                  956
# Unnamed: 0_y            956
# complete                956
# director_y              956
# genre                   956
# metacritic_page         956
# metascore               956
# num_critic_reviews      956
# num_user_ratings        956
# num_user_reviews        956
# rating                  956
# release_date            956
# runtime_minutes         956
# studio                  956
# user_score              956
# year_y                  956
# dtype: int64
